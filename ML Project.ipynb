# %%
# !pip install pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\harshitha\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\harshitha\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: scikit-learn in c:\users\harshitha\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\harshitha\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harshitha\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harshitha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harshitha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harshitha\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\harshitha\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harshitha\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harshitha\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\harshitha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# Sample data
data = {
    "Hours_Studied": [1, 2, 3, 4, 5],
    "Marks": [20, 40, 50, 70, 90]
}

df = pd.DataFrame(data)

# Input (X) and Output (y)
X = df[["Hours_Studied"]]
y = df["Marks"]

# Create and train model
model = LinearRegression()
model.fit(X, y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
predicted_marks = model.predict([[6]])

print("Predicted marks for 6 hours of study:", predicted_marks[0])
# Out:
# Predicted marks for 6 hours of study: 105.00000000000001
# C:\Users\HARSHITHA\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)
plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")
plt.show()

# %%
plt.scatter(X, y)

plt.plot(X, model.predict(X))

plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Linear Regression Model")
plt.show()

# %%
predicted_marks = model.predict(
    pd.DataFrame({"Hours_Studied": [8]})
)

print(predicted_marks[0])
# Out:
# 139.0
